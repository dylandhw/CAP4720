# %%
import pygame
import moderngl
import numpy
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pygame.init()
# Out:
# (5, 0)

# %%
width = height = 600

pygame.display.set_mode((width, height), flags = pygame.OPENGL | pygame.DOUBLEBUF)
pygame.display.set_caption(title = "test window")
gl = moderngl.get_context()

# %%
gl.info["GL_VERSION"]
# Out:
# '4.6 (Compatibility Profile) Mesa 24.2.8-1ubuntu1~24.04.1'

# %%
position_data = [
    0.0, 0.8,
    -0.8, -0.8,
    0.8, -0.8
]
triangle_vertex_positions = numpy.array(position_data).astype("float32")

# %%
triangle_positions_buffer = gl.buffer(triangle_vertex_positions)

# %%
vertex_shader_code = '''
#version 330 core

layout (location = 0) in vec2 position; 

void main(){
    gl_Position = vec4(position, 0.0, 1.0);
}
'''

# %%
fragment_shader_code = '''
#version 330 core

out vec4 outColor;

void main(){
    outColor = vec4(1.0, 1.0, 0.0, 1.0);
}
'''

# %%
program = gl.program(
    vertex_shader = vertex_shader_code,
    fragment_shader = fragment_shader_code,
)

# %%
renderable = gl.vertex_array(program, [(triangle_positions_buffer, '2f', 'position')])

# %%
running = True 

while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT or (event.type == pygame.KEYDOWN and event.key == 27):
            running = False
    gl.clear(0.50196078431, 0.50196078431, 0.0)
    renderable.render()
    pygame.display.flip()
pygame.quit()
