# %%
import pygame
import moderngl
import numpy

# %%
pygame.init()

# %%
width = height = 600

pygame.display.set_mode((width, height), flags = pygame.OPENGL | pygame.DOUBLEBUF)
pygame.display.set_caption(title = "Assignment 02: Dylan Wilkins")
gl = moderngl.get_context()

# %%
gl.info["GL_VERSION"]

# %%
position_data = [
    0.0, 0.8,
    -0.8, -0.8,
    0.8, -0.8
]
triangle_vertex_positions = numpy.array(position_data).astype("float32")

# %%
triangle_positions_buffer = gl.buffer(triangle_vertex_positions)

# %%
vertex_shader_code = '''
#version 330 core

// attribute variables go here

void main(){
}
'''

# %%
fragment_shader_code = '''
#version 330 core

// output variables here

void main(){
}
'''
